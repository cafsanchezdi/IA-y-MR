# %% [markdown]
# para el punto numero 2 se ha decicido utilizar la simulacion de netlogo llamada brians Brain, este modelo tiene las siguientes propiedades:
#
#
#
# 1.   las celulas blancas siempre se vuelven unas celulas rojas en el siguiente intervalo en el tiempo
# 2.   una celula roja siempre se vuelve una negra en el siguiente intervalo en el tiempo
# 3.   una celula blanca siempre nace cuando de una celula negra que tiene exactaente 2 vecinos blancos en sus celdas
#
# con estos parametros definidos procedemos a ejecutar la simulacion en netlogo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# despues de ejecutarlo multiples veces podemos ver que eventualmente hay un momvimiento en dos dimensiones y que el estado inicial se ha disipado

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# el siguiente patron tiene la propiedad de que realiza un movimiento horizontal a la izquieda

# %% [markdown]
# image.png

# %% [markdown]
# y este posee un movimiento horizontal a la derecha
#
#
# image.png

# %% [markdown]
# tambien se observa que este tiene un movimiento vertical superior
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# este es el estado actual, tras dejar la simulacion correr un periodo de tiempo se llega a este estado
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# el cual se repetira eternamente hasta que se introduzca un cambio
