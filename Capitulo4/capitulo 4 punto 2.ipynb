# %% [markdown]
# se ha ejecutado el ejemplo binario llamado cancer 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Viendo el resultado podemos ver que entre mas entrenamientos sse hace el promedio y el mejor se acecrcan bastante
