# %% [markdown]
# se han tomado datos e las TRM, valor del barril de crudo y accion de bancolombia de la pagina de yahoo finance y la trm de https://www.datos.gov.co/Econom-a-y-Finanzas/Tasa-de-Cambio-Representativa-del-Mercado-Historic/mcec-87by/data

# %% [markdown]
# con esto se armo la tabla para entrenar el modelo usando mepx
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# al ejecutar este codigo se obtiene lo siguiente
# ![image.png](data:image/png;base64,...)
