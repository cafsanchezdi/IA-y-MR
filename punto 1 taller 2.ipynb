# %% [markdown]
# Para definir las reglaws simples de los comportamientos en la universidad se podria definir los siguientes comportamientos y las siguientes reglas:
#
# en el salon de clase, la celula serian los estudiantes:
#
# 1.   Si 2 estudiantes en la vecinidad de un estudiante se encuentran tomando apuntes, significa que el estudiante debe tomar apuntes
# 2.   Si hay mas de 2 estudiantes en la vecinidad que no estan tomando apuntes el estudiante no tomara apuntes
# 3.   un estudiante que no toma apuntes se volvera un disruptor en el siguiente estado
# 4. cualquier estudiante con un disruptor como vecino dejara de tomar apuntes en el siguiente estado
